# %% [markdown]
# # AEON

# %% [markdown]
# В этой лекции мы более подробно поработаем с библиотекой aeon
#
# Aeon — это совместимый с scikit-learn набор инструментов для работы с временными рядами (TSML). Он организован в
# модули для различных задач обучения: классификация, регрессия, кластеризация, прогнозирование, обнаружение аномалий, сегментация и поиск по сходству.
#
# Aeon - хорошо документированная библиотека, имеет большое количество блокнотов, доступных в [документации](https://www.aeon-toolkit.org/en/stable/). Эта работа составлена на основе блокнотов, представленных в руководстве.
#
# Будем использовать для примера наборы данных ЭЭГ. Все используемые типы данных представляют собой трехмерные массивы (3D numpy arrays).

# %% [markdown]
# # Структуры данных и наборы данных
#
# *aeon* предполагает, что один временной ряд представляет собой двумерный массив формы `(n_channels, n_timepoints)`.
#
# Классификаторы и регрессоры принимают входные коллекции временных рядов (и наследуют от BaseCollectionEstimator).
#
# Если все серии имеют одинаковую длину, лучше всего работает с трехмерной фигурой `(n_cases, n_channels, n_timepoints)`.
#
# Серии разной длины хранятся в списках 2D numpy, но примеры, которые мы собираемся использовать, будут иметь одинаковую длину.
#
# В этом уроке в качестве рабочего примера будут использоваться данные ЭЭГ.
#
# Классификационный набор данных состоит из показаний ЭЭГ, снятых у испытуемого в состоянии покоя или при выполнении заданной задачи (поднятие рук). Полную информацию об этих данных можно найти в [блокноте](https://github.com/aeon-toolkit/aeon-neuro/blob/main/examples/data_loading.ipynb).
#
# *aeon* поставляется с некоторыми стандартными наборами данных UCR и UEA, и их все можно загрузить непосредственно с [timeseriesclassification.com](https://timeseriesclassification.com).

# %% [markdown]
# # Содержание
#
# * [Меры расстояний](#distance-tsc)
# * [Distance-based univariate Time Series Classification (TSC)](#classification)
# * [Distance-based  Time Series Extrinsic Regression](#regres)
# * [Подходы, основанные на свертках](#conv)
# * [Feature based classification and regression](#feature)
# * [Deep Learning подходы](#deep)
# * [Упражнения](#tasks)

# %% [markdown]
# ## Меры расстояний  <a id="distance-tsc"></a>
# Подходы, основанные на сходстве, были одним из первых предложений по классификации и регрессии временных рядов. Более того, эти типы методов также распространены для выполнения других задач временных рядов, таких как кластеризация или обнаружение аномалий и других.
#
# В первой части этой тетради представлены расстояния, реализованные в эоне, начиная с самого простого — евклидова расстояния. Затем он представляет расстояние динамического искажения времени (DTW), его варианты, такие как Amerced DTW (ADTW) или Shape DTW (ShapeDTW), а также некоторые другие альтернативные расстояния, такие как Move-Split-Merge (MSM).
#
# Во второй части этого блокнота мы демонстрируем использование этих расстояний в сочетании с классификатором KNearestNeighbours из scikit-learn, а также более подходящую реализацию KNearestNeighbours для временных рядов, включенных в aeon. Аналогичным образом также представлены подходы к работе с наборами данных TSER с использованием дистанционных подходов.
#
# Документация aeon содержит записные книжки по   [растоянию](https://www.aeon-toolkit.org/en/stable/examples/distances/distances.html) and [классификации на основе дистанции](https://www.aeon-toolkit.org/en/stable/examples/classification/distance_based.html) и искользования `aeon` расстояних с [`scikit-learn`](https://www.aeon-toolkit.org/en/stable/examples/distances/sklearn_distances.html).

# %%
# %pip install aeon[all_extras]
# %mkdir -p dataset
# Out:
# Collecting aeon[all_extras]
#   Downloading aeon-1.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting deprecated>=1.2.13 (from aeon[all_extras])
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numba<0.64.0,>=0.55 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (0.60.0)
# Requirement already satisfied: numpy<2.5.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (26.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (2.2.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (1.6.1)
# Requirement already satisfied: scipy<1.18.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (1.16.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (4.15.0)
# Collecting esig>=1.0.0 (from aeon[all_extras])
#   Downloading esig-1.0.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (1.10.1)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (0.14.1)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (3.10.0)
# Collecting pycatch22>=0.4.5 (from aeon[all_extras])
#   Downloading pycatch22-0.4.5.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyod>=1.1.3 (from aeon[all_extras])
#   Downloading pyod-3.2.1-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pydot>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (4.0.1)
# Collecting ruptures>=1.1.9 (from aeon[all_extras])
#   Downloading ruptures-1.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (0.13.2)
# Collecting sparse (from aeon[all_extras])
#   Downloading sparse-0.18.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (0.14.6)
# Requirement already satisfied: stumpy>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (1.13.0)
# Requirement already satisfied: tensorflow>=2.14 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (2.19.0)
# Requirement already satisfied: keras>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (3.13.2)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (2.10.0+cpu)
# Requirement already satisfied: tsfresh>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from aeon[all_extras]) (0.21.1)
# Collecting tslearn>=0.5.2 (from aeon[all_extras])
#   Downloading tslearn-0.8.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.13->aeon[all_extras]) (2.1.2)
# Collecting pyrecombine (from esig>=1.0.0->aeon[all_extras])
#   Downloading pyrecombine-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting roughpy (from esig>=1.0.0->aeon[all_extras])
#   Downloading roughpy-0.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->aeon[all_extras]) (0.24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (0.19.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.6.0->aeon[all_extras]) (0.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.2->aeon[all_extras]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.64.0,>=0.55->aeon[all_extras]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->aeon[all_extras]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->aeon[all_extras]) (2026.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from pyod>=1.1.3->aeon[all_extras]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8.0,>=1.6.0->aeon[all_extras]) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.12.1->aeon[all_extras]) (1.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (1.80.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.14->aeon[all_extras]) (2.19.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->aeon[all_extras]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->aeon[all_extras]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->aeon[all_extras]) (3.1.6)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.12/dist-packages (from tsfresh>=0.20.0->aeon[all_extras]) (1.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from tsfresh>=0.20.0->aeon[all_extras]) (3.1.2)
# Collecting numba<0.64.0,>=0.55 (from aeon[all_extras])
#   Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba<0.64.0,>=0.55->aeon[all_extras])
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->aeon[all_extras]) (0.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.14->aeon[all_extras]) (0.46.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->aeon[all_extras]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->aeon[all_extras]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->aeon[all_extras]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->aeon[all_extras]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->aeon[all_extras]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.14->aeon[all_extras]) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.1->aeon[all_extras]) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.14->aeon[all_extras]) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.14->aeon[all_extras]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow>=2.14->aeon[all_extras]) (3.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.1->aeon[all_extras]) (3.0.3)
# Requirement already satisfied: intel_openmp in /usr/local/lib/python3.12/dist-packages (from pyrecombine->esig>=1.0.0->aeon[all_extras]) (2025.3.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.6.0->aeon[all_extras]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.6.0->aeon[all_extras]) (2.20.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->aeon[all_extras]) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->aeon[all_extras]) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->aeon[all_extras]) (0.0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.6.0->aeon[all_extras]) (0.1.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.3.3 in /usr/local/lib/python3.12/dist-packages (from intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (2025.3.3)
# Requirement already satisfied: umf==1.0.* in /usr/local/lib/python3.12/dist-packages (from intel-cmplr-lib-ur==2025.3.3->intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (1.0.3)
# Requirement already satisfied: tcmlib>=1.4 in /usr/local/lib/python3.12/dist-packages (from umf==1.0.*->intel-cmplr-lib-ur==2025.3.3->intel_openmp->pyrecombine->esig>=1.0.0->aeon[all_extras]) (1.4.1)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading esig-1.0.0-py3-none-any.whl (19 kB)
# Downloading pyod-3.2.1-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.7/364.7 kB 11.3 MB/s eta 0:00:00
# Downloading ruptures-1.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.6 MB/s eta 0:00:00
# Downloading tslearn-0.8.1-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.9/387.9 kB 9.3 MB/s eta 0:00:00
# Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 55.3 MB/s eta 0:00:00
# Downloading aeon-1.4.0-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 44.3 MB/s eta 0:00:00
# Downloading sparse-0.18.0-py2.py3-none-any.whl (151 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.9/151.9 kB 9.2 MB/s eta 0:00:00
# Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# Downloading pyrecombine-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 75.0 MB/s eta 0:00:00
# Downloading roughpy-0.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 37.7 MB/s eta 0:00:00
# Building wheels for collected packages: pycatch22
#   Building wheel for pycatch22 (pyproject.toml) ... done
#   Created wheel for pycatch22: filename=pycatch22-0.4.5-cp312-cp312-linux_x86_64.whl size=113892 sha256=1394310a46bff30be26c92dfa111141c5ddf605c16a5b84f975a4d4c21765e48
#   Stored in directory: /root/.cache/pip/wheels/89/44/33/6f846a24d9908b045e0e6b7d8a4e66adc4dec8fdf14184c90c
# Successfully built pycatch22
# Installing collected packages: pycatch22, roughpy, llvmlite, deprecated, ruptures, numba, tslearn, sparse, pyod, aeon, pyrecombine, esig
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# Successfully installed aeon-1.4.0 deprecated-1.3.1 esig-1.0.0 llvmlite-0.46.0 numba-0.63.1 pycatch22-0.4.5 pyod-3.2.1 pyrecombine-1.0.1 roughpy-0.3.0 ruptures-1.1.10 sparse-0.18.0 tslearn-0.8.1

# %% [markdown]
# Чтобы использовать следующие команды, нужно убедиться, что wget установлен в вашей системе
# Скачать нужную версию wget можно с официального сайта  https://eternallybored.org/misc/wget/
# После скачивания - положить wget.exe сюда C:\Windows\System32
#
# Проблема windows еще и в том, что в powershell установлены allias  для iwr, curl, wget. При попытке к запустить эти команды будет запускаться виндовская Invoke-WebRequest .
# Поэтому или запускать с указанием расширения (например, wget.exe), или измненить алиас. Сделать это можно следующим образом.
#
# 1. Запускаем powershell или cmd.
#
# 2. Смотрим, что привязано к комманде wget:
# Get-Alias -Name wget
#
# 3. Если видите ответ типа "Alias           wget -> Invoke-WebRequest", то удаляем алиас:
# Remove-Item -Path Alias:\wget
#
# 4. Проверяем командой 2. Должно выдать ошибку.
#
# 5. Устанавливаем новый алиас
# New-Alias wget wget.exe
#
# Все, спокойно пользуемся привычным wget - ом.

# %%
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts -P dataset/
# Out:
# --2026-04-23 20:31:51--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TRAIN.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 367415 (359K) [text/plain]
# Saving to: ‘dataset/KDD_MTSC_TRAIN.ts’
#
# KDD_MTSC_TRAIN.ts   100%[===================>] 358.80K  --.-KB/s    in 0.02s
#
# 2026-04-23 20:31:52 (18.7 MB/s) - ‘dataset/KDD_MTSC_TRAIN.ts’ saved [367415/367415]
#
# --2026-04-23 20:31:52--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 366653 (358K) [text/plain]
# Saving to: ‘dataset/KDD_MTSC_TEST.ts’
#
# KDD_MTSC_TEST.ts    100%[===================>] 358.06K  --.-KB/s    in 0.03s
#
# 2026-04-23 20:31:52 (13.2 MB/s) - ‘dataset/KDD_MTSC_TEST.ts’ saved [366653/366653]
#
# --2026-04-23 20:31:52--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92720 (91K) [text/plain]
# Saving to: ‘dataset/KDD_UTSC_TRAIN.ts’
#
# KDD_UTSC_TRAIN.ts   100%[===================>]  90.55K  --.-KB/s    in 0.008s
#
# 2026-04-23 20:31:53 (10.6 MB/s) - ‘dataset/KDD_UTSC_TRAIN.ts’ saved [92720/92720]
#
# --2026-04-23 20:31:53--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92586 (90K) [text/plain]
# Saving to: ‘dataset/KDD_UTSC_TEST.ts’
#
# KDD_UTSC_TEST.ts    100%[===================>]  90.42K  --.-KB/s    in 0.01s
#
# 2026-04-23 20:31:53 (6.98 MB/s) - ‘dataset/KDD_UTSC_TEST.ts’ saved [92586/92586]
#
# --2026-04-23 20:31:53--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TRAIN.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456962 (446K) [text/plain]
# Saving to: ‘dataset/KDD_MTSER_TRAIN.ts’
#
# KDD_MTSER_TRAIN.ts  100%[===================>] 446.25K  --.-KB/s    in 0.03s
#
# 2026-04-23 20:31:54 (17.1 MB/s) - ‘dataset/KDD_MTSER_TRAIN.ts’ saved [456962/456962]
#
# --2026-04-23 20:31:54--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456342 (446K) [text/plain]
# Saving to: ‘dataset/KDD_MTSER_TEST.ts’
#
# KDD_MTSER_TEST.ts   100%[===================>] 445.65K  --.-KB/s    in 0.03s
#
# 2026-04-23 20:31:54 (16.1 MB/s) - ‘dataset/KDD_MTSER_TEST.ts’ saved [456342/456342]
#
# --2026-04-23 20:31:54--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TRAIN.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117424 (115K) [text/plain]
# Saving to: ‘dataset/KDD_UTSER_TRAIN.ts’
#
# KDD_UTSER_TRAIN.ts  100%[===================>] 114.67K  --.-KB/s    in 0.01s
#
# 2026-04-23 20:31:54 (10.6 MB/s) - ‘dataset/KDD_UTSER_TRAIN.ts’ saved [117424/117424]
#
# --2026-04-23 20:31:54--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117219 (114K) [text/plain]
# Saving to: ‘dataset/KDD_UTSER_TEST.ts’
#
# KDD_UTSER_TEST.ts   100%[===================>] 114.47K  --.-KB/s    in 0.02s
#
# 2026-04-23 20:31:55 (6.95 MB/s) - ‘dataset/KDD_UTSER_TEST.ts’ saved [117219/117219]

# %%
# это опционально, если хотите видеть все ворнинги - не запускайте эту ячейку

import warnings

warnings.filterwarnings("ignore")

# %%
from aeon.datasets import load_from_ts_file

# Загрузите одномерный набор данных TSC как двумерный массив NumPy

X_train_utsc, y_train_utsc = load_from_ts_file("./dataset/KDD_UTSC_TRAIN.ts", return_type="numpy2D")
X_test_utsc, y_test_utsc = load_from_ts_file("./dataset/KDD_UTSC_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSC problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSC problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSC problem train shape: (40, 100)
# Single channel EEG TSC problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных в виде трехмерного массива numpy

X_train_mtsc, y_train_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TRAIN.ts")
X_test_mtsc, y_test_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TEST.ts")

print("Four channel EEG TSC problem train shape:", X_train_mtsc.shape)
print("Four channel EEG TSC problem test shape:", X_test_mtsc.shape)
# Out:
# Four channel EEG TSC problem train shape: (40, 4, 100)
# Four channel EEG TSC problem test shape: (40, 4, 100)

# %%
# Загрузите одномерный набор данных TSER как двумерный массив numpy
X_train_utser, y_train_utser = load_from_ts_file("./dataset/KDD_UTSER_TRAIN.ts", return_type="numpy2D")
X_test_utser, y_test_utser = load_from_ts_file("./dataset/KDD_UTSER_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSER problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSER problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSER problem train shape: (40, 100)
# Single channel EEG TSER problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных TSER в виде трехмерного массива numpy
X_train_mtser, y_train_mtser = load_from_ts_file("./dataset/KDD_MTSER_TRAIN.ts")
X_test_mtser, y_test_mtser = load_from_ts_file("./dataset/KDD_MTSER_TEST.ts")

print("Four channel EEG TSER problem train shape:", X_train_mtser.shape)
print("Four channel EEG TSER problem test shape:", X_test_mtser.shape)
# Out:
# Four channel EEG TSER problem train shape: (72, 4, 100)
# Four channel EEG TSER problem test shape: (72, 4, 100)

# %% [markdown]
# Для наших примеров измерения расстояния давайте определим два разных случайных одномерных временных ряда (a и b) длиной m=10 и построим их график.

# %%
from aeon.testing.data_generation import make_example_1d_numpy
import seaborn as sns
import matplotlib.pyplot as plt

a = make_example_1d_numpy(n_timepoints=10, random_state=0)
b = make_example_1d_numpy(n_timepoints=10, random_state=1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

plt.show()

# %% [markdown]
# #### Euclidean Distance (direct alignment)

# %%
# Считаем по формуле вручную

import numpy as np

ED = np.sqrt(np.sum(np.power(a-b,2)))

print(f"The Euclidean distance between a and b is {ED}")
# Out:
# The Euclidean distance between a and b is 1.236743116180222

# %%
# Используем aeon

from aeon.distances import euclidean_distance

print(
    f"The Euclidean distance computed in aeon between a and b is",
    f"{euclidean_distance(a, b)}"
)
# Out:
# The Euclidean distance computed in aeon between a and b is 1.2367431161802223

# %%
# Постройте расстояния временных рядов поточечно, следуя по пути.
def plot_time_series_distances(a, b, cost_matrix, path):
    sns.lineplot(data=a, label=r"$\mathbf{a}$")
    sns.lineplot(data=b, label=r"$\mathbf{b}$")

    # соединить точки на пути
    for i in range(len(path)):
        plt.plot(
            [path[i][0], path[i][1]],
            [a[path[i][0]], b[path[i][1]]],
            'k--',
            alpha=0.2
        )
        plt.text(
            (path[i][0]+path[i][1])/2,
            (a[path[i][0]]+b[path[i][1]])/2,
            f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
        )

    return plt

# Вычислите квадрат матрицы расстояний между a и b.
def squared_pointwise_distance(a, b):
    n_timesteps = len(a)
    distances_matrix = np.zeros((n_timesteps, n_timesteps))

    for i in range(n_timesteps):
        for j in range(n_timesteps):
            distances_matrix[i, j] = (a[i]-b[j])**2

    return distances_matrix


cost_matrix = squared_pointwise_distance(a,b)
path = [(i, i) for i in range(len(a))]

ax = plot_time_series_distances(a, b, cost_matrix, path)

plt.show()

# %% [markdown]
# Евклидово расстояние также можно определить как квадратный корень из суммы квадратов разностей значений на диагонали всех возможных расстояний между элементами в обоих временных рядах.
#
# Прежде всего, мы вычисляем матрицу расстояний, которая содержит расстояния для всех элементов обоих временных рядов:

# %%
from aeon.visualisation.distances._pairwise_distance_matrix import plot_pairwise_distance_matrix

# Compute the squared pointwise distances between a and b
distance_matrix = squared_pointwise_distance(a, b)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(distance_matrix, a, b, path)
plt.show()

# %% [markdown]
# #### Гибкое расстояние: динамическое искажение времени (DTW)
#  DTW допускает выравнивание по временным шагам, т. е. не обязательно выравнивать временные шаги, а только первый и последний временные шаги.
#
# В этом первом примере мы позволяем DTW иметь последовательные выравнивания, продвигающиеся не более чем на один временной шаг в каждой серии.

# %%
from aeon.distances import dtw_distance

print(
    f"The DTW distance computed in aeon between a and b is",
    f"{dtw_distance(a, b, window=0.1)}"
)
# Out:
# The DTW distance computed in aeon between a and b is 1.1985498275436108

# %%
from aeon.distances import dtw_alignment_path, dtw_cost_matrix

path, _ = dtw_alignment_path(a, b, window=0.1)
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

# join the points in the path
for i in range(len(path)):
    plt.plot([path[i][0], path[i][1]], [a[path[i][0]], b[path[i][1]]], 'k--', alpha=0.2)
    plt.text(
        (path[i][0]+path[i][1])/2,
        (a[path[i][0]]+b[path[i][1]])/2,
        f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
    )

plt.show()

# %% [markdown]
# Сравните графики DTW и декартового расстояния. Какие выводы?

# %% [markdown]
# Как можно заметить, теперь расстояния не вычисляются для одних и тех же моментов времени. Они
# рассчитываются с учетом коллиндантных моментов времени.
#
# В этом случае расстояние — это путь с минимальной стоимостью, который удовлетворяет вышеупомянутым условиям.
#
# Ограничения:
#
# (Обратите внимание, что для удобства чтения пути начальная позиция должна быть последней,
# в данном случае (9,9), и мы перемещаем ближайшую точку времени. Например, из (9,9) мы
# может перейти в: A) (8, 9) со стоимостью 1,32, B) (8, 8) со стоимостью 1,32 или C) (9, 8)
# со стоимостью 1,17. Последнее - правильный выбор.)

# %%
path, dtw_dist = dtw_alignment_path(a, b, window=0.1)
print(f"DTW distance between a and b is {dtw_dist}.")
# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance between a and b is 1.1985498275436108.

# %% [markdown]
# Важно знать, что  DTW может быть более терпимой и предоставлять более широкие возможности выравнивания временных рядов. Чтобы контролировать такое поведение, мы определяем еще одно ограничение: размер окна.
#
# Это ограничение окон позволяет избежать выравнивания точек, разделенных более чем определенным процентом от длины временного ряда. Другими словами, если ограничение окна равно $w$, выравнивание $i$-й точки можно выполнить только с точками из интервала
#
# $[i - \lfloor w*m \rfloor, i + \lfloor w*m \rfloor]$.
#
# В предыдущем сценарии не использовался размер окна (эквивалент ограничения окна $w=1$.).
#
# Теперь, если мы уменьшим длину окна до $w=0,5$, мы увидим, что путь изменился:

# %%
w = 0.5
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.5 between a and b is 0.8566491595090396.

# %% [markdown]
# Посмотрим, что будет при ограничении окна в 20%.

# %%
w = 0.2
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.2 between a and b is 0.9199809594402144.

# %% [markdown]
# Можем посмотреть, какие варианты DTW реализованы в aeon. И сравнить получаемые расстояния.

# %%
from aeon.distances._distance import DISTANCES

# These are the DTW variants available in aeon for time series:
dtw_variants = [d["name"] for d in DISTANCES if 'dtw' in d["name"]]
print(f"DTW variants available in aeon: {dtw_variants}")
# Out:
# DTW variants available in aeon: ['dtw', 'dtw_gi', 'ddtw', 'wdtw', 'wddtw', 'adtw', 'shape_dtw', 'soft_dtw']

# %%
from aeon.distances import get_distance_function

for variant in dtw_variants:
    distance_function = get_distance_function(variant)
    distance = distance_function(a, b, window=0.2)
    print(f"{variant} distance between a and b is {distance}")
# Out:
# dtw distance between a and b is 0.9199809594402144
# dtw_gi distance between a and b is 0.9199809594402144
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.41867594005282865
# wddtw distance between a and b is 0.13960840776560768
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.074455734012375

# %% [markdown]
# Посмотрим, какие вообще метрики расстояния раелизованы в aeon и сравним их.

# %%
for dist in DISTANCES:
    try:
        print(f"{dist['name']} distance between a and b is {dist['distance'](a, b)}")
    except TypeError as err:
        print(f"{dist['name']} - {err}")
# Out:
# euclidean distance between a and b is 1.2367431161802223
# squared distance between a and b is 1.5295335354191666
# manhattan distance between a and b is 3.3323904398054873
# minkowski distance between a and b is 1.2367431161802223
# dtw distance between a and b is 0.6574923997015053
# dtw_gi distance between a and b is 0.6574923997015053
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.3235461427240929
# wddtw distance between a and b is 0.13960840776560768
# lcss distance between a and b is 0.0
# erp distance between a and b is 3.021868759085019
# edr distance between a and b is 0.8
# twe distance between a and b is 6.5094056644333955
# msm distance between a and b is 3.3323904398054873
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.740090024872542
# sbd distance between a and b is 0.3633143104636233
# shift_scale distance between a and b is 0.5568073651552791
# dft_sfa - not enough arguments: expected 3, got 2
# paa_sax - not enough arguments: expected 4, got 2
# sax - not enough arguments: expected 4, got 2
# sfa - not enough arguments: expected 3, got 2
# mpdist distance between a and b is 0.0

# %% [markdown]
# # Distance-based  Time Series Classification (TSC) <a id="classification"></a>
#
# ## Univariate Time Series
#
# Одним из первых способов классификации набора временных рядов является использование k-ближайшего
# подход соседей (kNN) в сочетании с соответствующей мерой расстояния временного ряда.
#
# Самый простой способ — использовать подход kNN «scikit-learn» в сочетании с определением расстояний.
# реализовано в `aeon`. Есть два разных способа:
#
# 1. Передайте функцию расстояния как вызываемую для параметра «метрика» в конструкторе.
#
# или
#
# 2. Установите в конструкторе для метрики значение «предварительно вычисленное» и передайте попарное расстояние.
# матрица для «подгонки» и «предсказания».
#
#
#
# В этом примере мы загружаем набор данных о прицеле, используя двумерный массив numpy, который имеет два размера (n_cases, n_timepoints), учитывая, что это принятый формат `scikit-learn`.
# Несмотря на то, что `aeon` позволяет использовать 2D-массивы, обычно предпочитает 3D-массивы в форма (n_cases, n_channels, n_timepoints).

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=3, metric=dtw_distance)
knn.fit(X_train_utsc, y_train_utsc)
predictions_utsc = knn.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc)
print(f"Accuracy of 1-NN (sklearn) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (sklearn) with DTW is 0.575

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier

knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance=dtw_distance)
knn_aeon.fit(X_train_utsc, y_train_utsc)
predictions_utsc_aeon = knn_aeon.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc_aeon)
print(f"Accuracy of 1-NN (aeon) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with DTW is 0.55

# %% [markdown]
# ## Distance-based Multivariate TSC (MTSC)
#
#
# Версия scikit-learn kNN не может быть применена к трехмерным массивам numpy. Однако, как мы только что видели, существует способ, которым расстояния временных рядов могут быть связаны с scikit-learn kNN: использование заранее вычисленных парных расстояний (в данном случае с расстоянием ADTW, чтобы показать разнообразие расстояний, включенных в `aeon`):

# %%
from aeon.distances import adtw_pairwise_distance, adtw_distance


train_dists = adtw_pairwise_distance(X_train_mtsc)
test_dists = adtw_pairwise_distance(X_test_mtsc, X_train_mtsc)

# scikit-learn KNN classifier with precomputed distances
knn = KNeighborsClassifier(metric="precomputed", n_neighbors=1)
knn.fit(train_dists, y_train_mtsc)
predictions_mtsc = knn.predict(test_dists)

print(
    f"Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is",
    f"{accuracy_score(y_test_mtsc, predictions_mtsc)}"
)
# Out:
# Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is 0.525

# %% [markdown]
# Теперь, если мы запустим подход kNN, специфичный для временных рядов, включенный в `aeon`, нам не нужно предварительно вычислять матрицу попарных расстояний, которая иногда может требовать больших вычислительных ресурсов и памяти.
#
# Для тех расстояний, которые уже реализованы в `aeon`, мы можем использовать их идентификатор вместо вызываемого расстояния. Например, расстояние ADTW обозначается как `adtw`.

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance=adtw_distance)
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance="adtw")
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %% [markdown]
# # Distance-based  Time Series Extrinsic Regression <a id='regres'></a>
#
# ## Univariate Time Series Extrinsic Regression (TSER)
#
# Рассмотрим два подхода к регрессии на основе двух метрик расстояния MSM и TWE.

# %%
from aeon.distances import (
    msm_pairwise_distance,
    twe_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

train_dists = msm_pairwise_distance(X_train_utser)
test_dists = msm_pairwise_distance(X_test_utser, X_train_utser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with MSM is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="msm")
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with MSM is {mse}")
# Out:
# MSE of 1-NN (sklearn) with MSM is 1.3942060469112671
# MSE of 1-NN (aeon) with MSM is 1.3942060469112671

# %%
# Now, for the TWE distance:
train_dists = twe_pairwise_distance(X_train_utser, window=0.1)
test_dists = twe_pairwise_distance(X_test_utser, X_train_utser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with TWE is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="twe",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with TWE is {mse}")
# Out:
# MSE of 1-NN (sklearn) with TWE is 1.7049822984745453
# MSE of 1-NN (aeon) with TWE is 1.7049822984745453

# %% [markdown]
# ## Distance-based Multivariate TSER (MTSER)

# %%
from aeon.distances import (
    erp_pairwise_distance,
    wdtw_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error


train_dists = erp_pairwise_distance(X_train_mtser)
test_dists = erp_pairwise_distance(X_test_mtser, X_train_mtser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with ERP is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="erp")
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with ERP is {mse}")
# Out:
# MSE of 1-NN (sklearn) with ERP is 1.0155583588945694
# MSE of 1-NN (aeon) with ERP is 1.0155583588945694

# %%
# Now, for the wdtw distance:
train_dists = wdtw_pairwise_distance(X_train_mtser, window=0.1)
test_dists = wdtw_pairwise_distance(X_test_mtser, X_train_mtser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with WDTW is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="wdtw",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with WDTW is {mse}")
# Out:
# MSE of 1-NN (sklearn) with WDTW is 1.3909486821400647
# MSE of 1-NN (aeon) with WDTW is 1.3909486821400647

# %% [markdown]
# ## Elastic Ensemble (EE) и Proximity Forest (PF)
#
# Другими более продвинутыми подходами являются EE и PF.
#
# EE представляет собой взвешенный ансамбль из 11 классификаторов 1-NN с рядом эластичных мер расстояния. Это требует перекрестной проверки весов каждого классификатора в ансамбле.
#
# В случае PF алгоритм представляет собой ансамбль высокорандомизированных деревьев близости, которые разветвляются по близости временных рядов к тому или иному образцовому временному ряду, а не по значениям атрибутов.

# %%
from aeon.classification.distance_based import ElasticEnsemble

ee = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble is 0.5.

# %% [markdown]
# Более конкретно, реализация EE в `aeon` позволяет выбирать заданные меры расстояния для построения ансамбля, а также изменять некоторые параметры процедуры перекрестной проверки:

# %%
ee = ElasticEnsemble(
    distance_measures=["dtw", "msm"],
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble with DTW and MSM is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble with DTW and MSM is 0.55.

# %% [markdown]
# Подход PF недавно был включен в `aeon` и на данный момент может решать только одномерные задачи TSC:

# %%
from aeon.classification.distance_based import ProximityForest

pf = ProximityForest(n_trees=10, random_state=0)
pf.fit(X_train_utsc, y_train_utsc)
pf_preds = pf.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, pf_preds)
print(f"Accuracy of Proximity Forest is {accuracy}.")
# Out:
# Accuracy of Proximity Forest is 0.525.

# %% [markdown]
# # Подходы, основанные на свертках <a id='conv'></a>
#
# ### Rocket
#
# RocketClassifier()
# Rocket — оригинальный сверточный метод классификации временных рядов.
#
# ### MiniRocket
# RocketClassifier(rocket_transform = "minirocket") — модификация Rocket, более точная.
#
# ###  Hydra
# HydraClassifier()
# HydraRegressor()
#
# Hydra — это вариант Rocket, который объединяет функции и методы подходов на основе словаря.
#
# Примечание. Гидра реализована с использованием torch. Для запуска этого кода вам понадобится установить его.
# pip install torch.
#
#
# ###  MultiRocket+Hydra
# MultiRocketHydraClassifier()
# MultiRocket+Hydra сочетает в себе подходы MultiRocket и Hydra.

# %%
from aeon.classification.convolution_based import RocketClassifier

classifier = RocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.425

# %%
from aeon.classification.convolution_based import MiniRocketClassifier

classifier = MiniRocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.9

# %%
from aeon.classification.convolution_based import  HydraClassifier

classifier = HydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.925

# %%
from aeon.classification.convolution_based import  MultiRocketHydraClassifier

classifier = MultiRocketHydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.875

# %%
from aeon.regression.convolution_based import MiniRocketRegressor
from sklearn.metrics import r2_score

regressor = MiniRocketRegressor(n_jobs=-1, random_state=42)
regressor.fit(X_train_mtser, y_train_mtser)
preds = regressor.predict(X_test_mtser)
r2_score(y_test_mtser, preds)
# Out:
# 0.4110569698148918

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, preds)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %%
# FineTuning parameters

from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from aeon.regression.convolution_based import MiniRocketRegressor

# ==============================================================================
# == fit =======================================================================
# ==============================================================================

param_grid = {
    "n_kernels" : [100, 1000, 10000],
    "max_dilations_per_kernel" : [16, 32, 64],
}

gs = GridSearchCV(
    MiniRocketRegressor(n_jobs=-1, random_state=42),
    param_grid,
)
gs.fit(X_train_mtser, y_train_mtser)

# ==============================================================================
# == plot results ==============================================================
# ==============================================================================

_scores = gs.cv_results_["mean_test_score"]
_params = np.array([f"d={_[0]}\nk={_[1]}" for _ in [tuple(_.values()) for _ in gs.cv_results_["params"]]])
_order = _scores.argsort()
_, a = plt.subplots(1, 1, figsize = (6, 4))
a.plot(_params[_order], _scores[_order], ".-")
a.set(xlabel = "d/k", ylabel = "r2")
plt.show()

# %%
# считаем скор для лучшей конфигурации
gs.score(X_test_mtser, y_test_mtser)
# Out:
# 0.3912922637298655

# %%
# смотри лучший набор

gs
# Out:
# GridSearchCV(estimator=MiniRocketRegressor(n_jobs=-1, random_state=42),
#              param_grid={'max_dilations_per_kernel': [16, 32, 64],
#                          'n_kernels': [100, 1000, 10000]})

# %% [markdown]
# # Feature based classification and regression <a id='feature'></a>
#
# Классификаторы и регрессоры на основе признаков являются популярной темой в классификации временных рядов (TSC) и регрессии (TSER).  В пригципе все такие модели представляют собой пайплайны из вытаскивателей фич и классификаторов/регрессоров.
#
# <img src="data/aeon/pipeline.png" alt="Pipeline classifier."><img>

# %%
# отрисуем наши данные

from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_mtsc[:,2,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_mtser[0].T)
plt.legend(["Dim 0", "Dim 1", "Dim 2", "Dim 3"])

# %% [markdown]
# ## Catch22 <a id='catch22'></a>
#
# Набор инструментов для сравнительного анализа временных рядов (hctsa) может создать более 7700 функций для исследовательского анализа временных рядов. К сожалению, в настоящее время в Python не существует полного набора этих функций, заинтересованные пользователи могут ознакомиться с соответствующей публикацией и исходным набором инструментов MATLAB.
#
# Канонические характеристики временных рядов (Catch22) представляют собой 22 характеристики hctsa, которые считаются наиболее дискриминационными из полного набора.
#
# Функции Catch22 были выбраны путем оценки наборов данных UCR. Характеристики hctsa изначально были сокращены: были удалены те, которые чувствительны к среднему значению и дисперсии, а также те, которые невозможно вычислить для более чем 80 % наборов данных UCR. Затем была проведена оценка функций на основе прогнозируемой производительности. Любые функции, производительность которых была ниже порогового значения, были удалены. Для остальных признаков была выполнена иерархическая кластеризация корреляционной матрицы для устранения избыточности. Из каждого из 22 сформированных кластеров был выбран один признак с учетом сбалансированной точности, вычислительной эффективности и интерпретируемости. Функции Catch22 охватывают широкий спектр понятий, таких как базовая статистика значений рядов данных, линейные корреляции и энтропия.
#
#
# <img src="data/aeon/catch22.png" alt="Catch22 extraction process."></img>

# %% [markdown]
# Класс Catch22 преобразует временные ряды в 22 признака.

# %%
from aeon.transformations.collection.feature_based import Catch22


c22 = Catch22()
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  6.92507633e-06,  2.98422388e+00,
#          4.00000000e+00, -8.88178420e-16, -1.01000518e-15,
#          0.00000000e+00,  1.60000000e+01,  1.11111111e-01,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.84615385e-02, -2.70000000e-01,  5.30000000e-01,
#          1.57359203e-10,  5.00000000e+00,  2.00785293e+00,
#          8.28571429e-01,  6.00000000e-01,  4.90873852e-01,
#          1.40193684e-05,  1.81815758e-06, -1.47671393e-06,
#          3.71562980e+00,  4.00000000e+00, -8.88178420e-16,
#         -5.87837340e-16,  0.00000000e+00,  1.70000000e+01,
#          6.25000000e-02,  0.00000000e+00,  0.00000000e+00,
#          3.00000000e+00,  4.54545455e-02, -2.30000000e-01,
#          4.90000000e-01,  7.77998115e-11,  7.00000000e+00,
#          2.00199666e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  1.02667064e-05, -6.81925616e-06,
#         -2.74171769e-06,  2.54465362e+00,  5.00000000e+00,
#         -8.88178420e-16, -4.07928862e-16,  0.00000000e+00,
#          1.20000000e+01,  4.00000000e-02,  0.00000000e+00,
#          0.00000000e+00,  4.00000000e+00,  5.26315789e-02,
#         -2.00000000e-01,  8.20000000e-01,  1.04053400e-10,
#          8.00000000e+00,  1.84997494e+00,  8.28571429e-01,
#          8.28571429e-01,  4.41786467e-01,  1.08579400e-05,
#         -4.28629432e-06, -2.09537733e-06,  2.25468230e+00,
#          5.00000000e+00, -8.88178420e-16, -1.96296224e-17,
#          0.00000000e+00,  1.30000000e+01,  6.36574074e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.50000000e-01, -9.00000000e-02,  8.00000000e-01,
#          3.78824191e-11,  5.00000000e+00,  1.94369228e+00,
#          1.71428571e-01,  8.00000000e-01,  5.39961237e-01,
#          7.16263022e-06],
#        [-4.93347026e-07, -4.41079953e-06,  9.76550866e-01,
#          5.00000000e+00, -8.88178420e-16, -1.93131216e-15,
#          0.00000000e+00,  1.00000000e+01,  1.47737765e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -6.00000000e-02, -5.60000000e-01,
#          1.02981595e-10,  6.00000000e+00,  2.08655852e+00,
#          1.71428571e-01,  8.28571429e-01,  7.36310778e-01,
#          1.60656562e-05,  1.06128379e-06,  4.37068609e-06,
#          2.99539703e+00,  1.00000000e+00, -8.88178420e-16,
#          2.19729828e-16,  0.00000000e+00,  1.50000000e+01,
#          2.08333333e-02,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  8.33333333e-02,  9.00000000e-02,
#         -8.80000000e-01,  8.84485984e-11,  5.00000000e+00,
#          2.05946536e+00,  6.00000000e-01,  3.14285714e-01,
#          2.94524311e-01,  9.62091285e-06, -9.48719145e-06,
#         -5.45880569e-06,  1.78980033e+00,  5.00000000e+00,
#         -8.88178420e-16,  5.16491517e-17,  0.00000000e+00,
#          1.20000000e+01,  6.12182430e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  6.66666667e-01,
#         -3.00000000e-01, -7.40000000e-01,  7.71939551e-11,
#          6.00000000e+00,  1.96831980e+00,  1.71428571e-01,
#          7.14285714e-01,  6.87223393e-01,  1.48956808e-05,
#         -2.88989693e-06, -4.87479978e-06,  2.21747187e+00,
#          5.00000000e+00, -8.88178420e-16,  7.57005863e-17,
#          0.00000000e+00,  1.20000000e+01,  9.23361034e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          2.00000000e-01, -3.00000000e-02, -7.50000000e-01,
#          3.72808238e-11,  4.00000000e+00,  2.04733206e+00,
#          1.71428571e-01,  6.85714286e-01,  4.41786467e-01,
#          7.52540169e-06],
#        [-6.72778723e-06,  2.23202708e-06,  8.30813700e-01,
#          1.00000000e+00, -8.88178420e-16,  1.16234122e-15,
#          0.00000000e+00,  1.10000000e+01,  1.73611111e-02,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          2.50000000e-01, -3.20000000e-01,  3.40000000e-01,
#          6.56303902e-11,  7.00000000e+00,  2.17460531e+00,
#          7.14285714e-01,  1.71428571e-01,  8.34485549e-01,
#          1.45365247e-05, -1.44995057e-06,  1.93312705e-06,
#          7.17005807e-01,  1.00000000e+00, -8.88178420e-16,
#         -8.69151397e-16,  0.00000000e+00,  1.20000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01, -6.00000000e-02,
#          3.20000000e-01,  3.23868358e-11,  4.00000000e+00,
#          2.16552480e+00,  8.00000000e-01,  8.00000000e-01,
#          1.32535940e+00,  1.07278852e-05, -1.83019499e-06,
#          7.62620939e-06,  2.41674894e+00,  5.00000000e+00,
#         -8.88178420e-16,  2.01394617e-16,  0.00000000e+00,
#          2.50000000e+01,  9.23361034e-03,  0.00000000e+00,
#          0.00000000e+00,  5.00000000e+00,  4.00000000e-01,
#         -2.70000000e-01, -3.80000000e-01,  9.72031604e-11,
#          6.00000000e+00,  1.94369228e+00,  8.00000000e-01,
#          7.42857143e-01,  4.41786467e-01,  1.12686720e-05,
#         -3.71330823e-06, -1.98429828e-06,  2.58492491e+00,
#          5.00000000e+00, -8.88178420e-16,  5.66426479e-17,
#          0.00000000e+00,  2.30000000e+01,  8.00000000e-02,
#          0.00000000e+00,  0.00000000e+00,  4.00000000e+00,
#          5.55555556e-02, -3.00000000e-02,  5.60000000e-01,
#          4.52016486e-11,  5.00000000e+00,  1.97770999e+00,
#          7.14285714e-01,  8.28571429e-01,  4.41786467e-01,
#          7.43561030e-06],
#        [ 1.06707589e-06,  5.06165512e-06,  9.40987016e-01,
#          4.00000000e+00, -8.88178420e-16, -1.18293308e-15,
#          0.00000000e+00,  1.20000000e+01,  1.23456790e-02,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          1.00000000e-01, -4.20000000e-01, -2.40000000e-01,
#          8.22614633e-11,  6.00000000e+00,  2.16264604e+00,
#          8.28571429e-01,  3.42857143e-01,  7.36310778e-01,
#          1.43699941e-05, -1.24257183e-06,  1.42709096e-06,
#          2.94247757e+00,  3.00000000e+00, -8.88178420e-16,
#         -2.50000611e-16,  0.00000000e+00,  1.50000000e+01,
#          4.62962963e-03,  0.00000000e+00,  0.00000000e+00,
#          2.00000000e+00,  1.25000000e-01,  2.20000000e-01,
#         -1.10000000e-01,  6.93500440e-11,  5.00000000e+00,
#          1.92542785e+00,  8.28571429e-01,  8.28571429e-01,
#          2.94524311e-01,  8.91888264e-06, -4.34236854e-06,
#         -1.88361756e-06,  2.63896118e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.92485890e-16,  0.00000000e+00,
#          1.50000000e+01,  2.20385675e-02,  0.00000000e+00,
#          0.00000000e+00,  3.00000000e+00,  1.11111111e-01,
#          2.90000000e-01, -2.50000000e-01,  6.96738164e-11,
#          6.00000000e+00,  2.00650422e+00,  8.28571429e-01,
#          8.28571429e-01,  3.43611696e-01,  9.74783003e-06,
#         -3.57222777e-06, -5.38267251e-06,  3.04652712e+00,
#          1.10000000e+01, -8.88178420e-16,  4.38125672e-17,
#          0.00000000e+00,  1.40000000e+01,  5.10204082e-03,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,
#          1.42857143e-01,  2.80000000e-01, -1.40000000e-01,
#          4.00538711e-11,  7.00000000e+00,  2.04099986e+00,
#          7.71428571e-01,  2.00000000e-01,  3.43611696e-01,
#          6.30681363e-06],
#        [ 5.41709902e-06,  2.05431239e-06,  8.54785389e-01,
#          3.00000000e+00, -8.88178420e-16, -1.76750953e-15,
#          0.00000000e+00,  1.00000000e+01,  3.67309458e-03,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.33333333e-01,  2.08166817e-17, -6.20000000e-01,
#          5.81324313e-11,  5.00000000e+00,  2.15525567e+00,
#          7.71428571e-01,  3.71428571e-01,  1.07992247e+00,
#          1.58005635e-05, -5.96238663e-07,  2.76329744e-06,
#          7.96695469e-01,  2.00000000e+00, -8.88178420e-16,
#         -5.99472331e-16,  0.00000000e+00,  9.00000000e+00,
#          1.93905817e-02,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  2.00000000e-01, -2.00000000e-02,
#         -5.50000000e-01,  3.29836877e-11,  5.00000000e+00,
#          2.14756047e+00,  8.00000000e-01,  8.28571429e-01,
#          1.27627202e+00,  1.12504263e-05,  5.73291371e-06,
#          2.48495087e-06,  1.59802527e+00,  4.00000000e+00,
#         -8.88178420e-16, -5.00682720e-16,  0.00000000e+00,
#          8.00000000e+00,  3.36700337e-03,  0.00000000e+00,
#          0.00000000e+00,  2.00000000e+00,  3.33333333e-01,
#         -1.90000000e-01,  6.90000000e-01,  4.75743565e-11,
#          6.00000000e+00,  2.11236435e+00,  1.71428571e-01,
#          8.28571429e-01,  6.38136008e-01,  1.26219064e-05,
#         -1.88620306e-07,  1.45344422e-06,  1.46937513e+00,
#          5.00000000e+00, -8.88178420e-16, -3.32636878e-17,
#          0.00000000e+00,  1.70000000e+01,  5.20355066e-03,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          3.33333333e-01,  8.00000000e-02, -1.50000000e-01,
#          2.18684364e-11,  5.00000000e+00,  2.03344937e+00,
#          1.71428571e-01,  8.28571429e-01,  6.38136008e-01,
#          7.81002358e-06]])

# %%
from aeon.transformations.collection.feature_based._catch22 import feature_names

feature_names
# Out:
# ['DN_HistogramMode_5',
#  'DN_HistogramMode_10',
#  'CO_f1ecac',
#  'CO_FirstMin_ac',
#  'CO_HistogramAMI_even_2_5',
#  'CO_trev_1_num',
#  'MD_hrv_classic_pnn40',
#  'SB_BinaryStats_mean_longstretch1',
#  'SB_TransitionMatrix_3ac_sumdiagcov',
#  'PD_PeriodicityWang_th0_01',
#  'CO_Embed2_Dist_tau_d_expfit_meandiff',
#  'IN_AutoMutualInfoStats_40_gaussian_fmmi',
#  'FC_LocalSimple_mean1_tauresrat',
#  'DN_OutlierInclude_p_001_mdrmd',
#  'DN_OutlierInclude_n_001_mdrmd',
#  'SP_Summaries_welch_rect_area_5_1',
#  'SB_BinaryStats_diff_longstretch0',
#  'SB_MotifThree_quantile_hh',
#  'SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1',
#  'SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1',
#  'SP_Summaries_welch_rect_centroid',
#  'FC_LocalSimple_mean3_stderr']

# %% [markdown]
# Преобразование можно настроить, и вы можете выбрать подмножество функций для извлечения. Параметр catch24 будет включать среднее и стандартное отклонение, а также исходные 22 функции.
#
# pycatch22 будет использовать библиотеку pycatch22, завернутую в C.

# %%
c22 = Catch22(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    catch24=True,
)
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  2.98422388e+00,  2.00785293e+00,
#         -4.84662295e-06,  1.63624369e-05,  1.81815758e-06,
#          3.71562980e+00,  2.00199666e+00,  4.07268745e-07,
#          1.16629572e-05, -6.81925616e-06,  2.54465362e+00,
#          1.84997494e+00, -2.73869572e-06,  1.30628441e-05,
#         -4.28629432e-06,  2.25468230e+00,  1.94369228e+00,
#         -3.51260400e-06,  8.11090668e-06],
#        [-4.93347026e-07,  9.76550866e-01,  2.08655852e+00,
#          1.43118551e-06,  1.57514418e-05,  1.06128379e-06,
#          2.99539703e+00,  2.05946536e+00,  4.93131265e-06,
#          1.18989896e-05, -9.48719145e-06,  1.78980033e+00,
#          1.96831980e+00, -3.01206374e-06,  1.42330289e-05,
#         -2.88989693e-06,  2.21747187e+00,  2.04733206e+00,
#         -2.96546855e-06,  8.23176010e-06],
#        [-6.72778723e-06,  8.30813700e-01,  2.17460531e+00,
#         -6.06350354e-07,  1.33059491e-05, -1.44995057e-06,
#          7.17005807e-01,  2.16552480e+00,  3.79695308e-06,
#          1.00766877e-05, -1.83019499e-06,  2.41674894e+00,
#          1.94369228e+00,  3.37033758e-06,  1.24823971e-05,
#         -3.71330823e-06,  2.58492491e+00,  1.97770999e+00,
#          8.40880283e-07,  8.31148145e-06],
#        [ 1.06707589e-06,  9.40987016e-01,  2.16264604e+00,
#         -2.17892949e-07,  1.41719989e-05, -1.24257183e-06,
#          2.94247757e+00,  1.92542785e+00, -2.02235649e-06,
#          1.04135837e-05, -4.34236854e-06,  2.63896118e+00,
#          2.00650422e+00, -2.30261793e-06,  1.08641355e-05,
#         -3.57222777e-06,  3.04652712e+00,  2.04099986e+00,
#         -2.96036604e-06,  7.47429838e-06],
#        [ 5.41709902e-06,  8.54785389e-01,  2.15525567e+00,
#          3.07705341e-06,  1.41351503e-05, -5.96238663e-07,
#          7.96695469e-01,  2.14756047e+00,  8.81621473e-09,
#          1.01270483e-05,  5.73291371e-06,  1.59802527e+00,
#          2.11236435e+00,  2.83706608e-06,  1.17155555e-05,
#         -1.88620306e-07,  1.46937513e+00,  2.03344937e+00,
#         -8.22774051e-07,  7.29112178e-06]])

# %% [markdown]
# Классы Catch22Classifier и Catch22Regressor в aeon — это просто удобные оболочки для конвейера преобразования Catch22 и случайного леса, обучаемого scikit-learn по умолчанию.

# %%
from aeon.classification.feature_based import Catch22Classifier
from sklearn.metrics import accuracy_score

c22_cls = Catch22Classifier(random_state=42)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.classification.sklearn import RotationForestClassifier

c22_cls = Catch22Classifier(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    estimator=RotationForestClassifier(),
    random_state=42,
)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.regression.feature_based import Catch22Regressor
from sklearn.metrics import mean_squared_error

c22_reg = Catch22Regressor(random_state=42)
c22_reg.fit(X_train_mtser, y_train_mtser)
c22_preds_r = c22_reg.predict(X_test_mtser)
mean_squared_error(y_test_mtser, c22_preds_r)
# Out:
# 0.7975235446926242

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, c22_preds_r)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Deep Leaning подходы <a id='deep'></a>
#
# Можно сказать, что на данном этапе модели глубокого обучения являются SOTA моделями для решения задач классификации и регрессии временных рядов.
#
#
# <img src="data/aeon/deep-legend.png" alt="Deep Legend."></img>

# %%
# Для классификации
# нормализуем по среднему и дисперсии наши ряды
X_train_c = (X_train_mtsc - X_train_mtsc.mean(axis=-1, keepdims=True)) / (X_train_mtsc.std(axis=-1, keepdims=True))
X_test_c = (X_test_mtsc - X_test_mtsc.mean(axis=-1, keepdims=True)) / (X_test_mtsc.std(axis=-1, keepdims=True))

print("Train shape:", X_train_c.shape)
print("Test shape:", X_test_c.shape)
# Out:
# Train shape: (40, 4, 100)
# Test shape: (40, 4, 100)

# %%
from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_c[:,0,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
# для регрессии

# znormalize the series
X_train_r = (X_train_mtser - X_train_mtser.mean(axis=-1, keepdims=True)) / (X_train_mtser.std(axis=-1, keepdims=True))
X_test_r = (X_test_mtser - X_test_mtser.mean(axis=-1, keepdims=True)) / (X_test_mtser.std(axis=-1, keepdims=True))

print("Train shape:", X_train_mtser.shape)
print("Test shape:", X_test_mtser.shape)
# Out:
# Train shape: (72, 4, 100)
# Test shape: (72, 4, 100)

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_r[:5,0,:].T)
plt.title("EEG Regression Samples")
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Multi Layer Perceptron (MLP)
#
#
# Многослойный персептрон (MLP), простейшая модель нейронных сетей, часто используется в качестве основы для моделей глубокого обучения. Однако применительно к данным временных рядов он не учитывает временные зависимости. Модель MLP пытается найти оптимальную нелинейную комбинацию входных функций для достижения хорошей производительности последующей задачи.
#
# <img src="data/aeon/MLP.png" alt="mlp"><i>

# %%
from aeon.classification.deep_learning import MLPClassifier
from sklearn.metrics import accuracy_score

mlp_cls = MLPClassifier(n_epochs=100)
mlp_cls.fit(X_train_c, y_train_mtsc)
mlp_cls_preds = mlp_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, mlp_cls_preds))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 0.5

# %%
from aeon.regression.deep_learning import MLPRegressor
from sklearn.metrics import mean_squared_error

mlp_rgs = MLPRegressor(n_epochs=500)
mlp_rgs.fit(X_train_r, y_train_mtser)
mlp_rgs_preds = mlp_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, mlp_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1.466228457820376

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, mlp_rgs_preds, title="MLP Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'MLP Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# ## The Fully Convolutional Neural Network (FCNRegressor)
#
#
# Полностью сверточные нейронные сети (FCN) все чаще используются для анализа временных рядов благодаря их способности эффективно улавливать локальные закономерности и многомасштабные зависимости.
#
# Сверточная нейронная сеть по времени (TimeCNN) — это сверточная нейронная сеть, в которой процесс оптимизации фокусируется на изучении наиболее эффективных фильтров для достижения оптимальных результатов. В отличие от MLP, TimeCNN использует локальные свертки, позволяя улавливать и учитывать временные зависимости в данных, что делает их более подходящими для анализа временных рядов.
#
# <img src="data/aeon/TimeCNN.png" alt="cnn"><i>

# %%
from aeon.classification.deep_learning import FCNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = FCNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 100, 128)       │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 100, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,058 (1.03 MB)
#  Trainable params: 268,034 (1.02 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7000 - loss: 0.5400 - learning_rate: 0.0010
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9750 - loss: 0.1445 - learning_rate: 0.0010
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 0.0706 - learning_rate: 0.0010
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0378 - learning_rate: 0.0010
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0230 - learning_rate: 0.0010
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0156 - learning_rate: 0.0010
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 1.0000 - loss: 0.0113 - learning_rate: 0.0010
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0086 - learning_rate: 0.0010
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.0069 - learning_rate: 0.0010
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0057 - learning_rate: 0.0010
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0049 - learning_rate: 0.0010
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 0.0043 - learning_rate: 0.0010
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0038 - learning_rate: 0.0010
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0034 - learning_rate: 0.0010
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0031 - learning_rate: 0.0010
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0029 - learning_rate: 0.0010
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0027 - learning_rate: 0.0010
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0025 - learning_rate: 0.0010
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0023 - learning_rate: 0.0010
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 1.0000 - loss: 9.9880e-04 - learning_rate: 0.0010
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - accuracy: 1.0000 - loss: 9.6986e-04 - learning_rate: 0.0010
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 1.0000 - loss: 9.4226e-04 - learning_rate: 0.0010
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 453ms/step - accuracy: 1.0000 - loss: 9.1596e-04 - learning_rate: 0.0010
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 795ms/step - accuracy: 1.0000 - loss: 8.9082e-04 - learning_rate: 0.0010
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 1.0000 - loss: 8.6679e-04 - learning_rate: 0.0010
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 1.0000 - loss: 8.4377e-04 - learning_rate: 0.0010
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 1.0000 - loss: 8.2172e-04 - learning_rate: 0.0010
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 1.0000 - loss: 8.0056e-04 - learning_rate: 0.0010
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 1.0000 - loss: 7.8023e-04 - learning_rate: 0.0010
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 7.6071e-04 - learning_rate: 0.0010
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 1.0000 - loss: 7.4193e-04 - learning_rate: 0.0010
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 1.0000 - loss: 7.2386e-04 - learning_rate: 0.0010
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 1.0000 - loss: 7.0650e-04 - learning_rate: 0.0010
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 1.0000 - loss: 6.8982e-04 - learning_rate: 0.0010
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 1.0000 - loss: 6.7376e-04 - learning_rate: 0.0010
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 6.5827e-04 - learning_rate: 0.0010
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 1.0000 - loss: 6.4333e-04 - learning_rate: 0.0010
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 1.0000 - loss: 6.2892e-04 - learning_rate: 0.0010
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 1.0000 - loss: 6.1499e-04 - learning_rate: 0.0010
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 1.0000 - loss: 6.0158e-04 - learning_rate: 0.0010
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 1.0000 - loss: 5.8864e-04 - learning_rate: 0.0010
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 1.0000 - loss: 5.7618e-04 - learning_rate: 0.0010
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 1.0000 - loss: 5.6409e-04 - learning_rate: 0.0010
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 1.0000 - loss: 5.5244e-04 - learning_rate: 0.0010
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 1.0000 - loss: 5.4116e-04 - learning_rate: 0.0010
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 1.0000 - loss: 5.3024e-04 - learning_rate: 0.0010
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 1.0000 - loss: 5.1966e-04 - learning_rate: 0.0010
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 1.0000 - loss: 5.0939e-04 - learning_rate: 0.0010
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 1.0000 - loss: 4.9945e-04 - learning_rate: 0.0010
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 1.0000 - loss: 4.8981e-04 - learning_rate: 0.0010
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 237ms/step - accuracy: 1.0000 - loss: 4.8044e-04 - learning_rate: 0.0010
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 1.0000 - loss: 4.7136e-04 - learning_rate: 0.0010
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 1.0000 - loss: 4.6254e-04 - learning_rate: 0.0010
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 1.0000 - loss: 4.5398e-04 - learning_rate: 0.0010
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 4.4567e-04 - learning_rate: 0.0010
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 4.3757e-04 - learning_rate: 0.0010
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 1.0000 - loss: 4.2973e-04 - learning_rate: 0.0010
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - accuracy: 1.0000 - loss: 4.2208e-04 - learning_rate: 0.0010
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 1.0000 - loss: 4.1467e-04 - learning_rate: 0.0010
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 1.0000 - loss: 4.0744e-04 - learning_rate: 0.0010
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 4.0041e-04 - learning_rate: 0.0010
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 1.0000 - loss: 3.9358e-04 - learning_rate: 0.0010
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 1.0000 - loss: 3.8694e-04 - learning_rate: 0.0010
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 1.0000 - loss: 3.8047e-04 - learning_rate: 0.0010
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - accuracy: 1.0000 - loss: 3.7417e-04 - learning_rate: 0.0010
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 1.0000 - loss: 3.6805e-04 - learning_rate: 0.0010
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 1.0000 - loss: 3.6209e-04 - learning_rate: 0.0010
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 3.5627e-04 - learning_rate: 0.0010
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 1.0000 - loss: 3.5060e-04 - learning_rate: 0.0010
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 1.0000 - loss: 3.4508e-04 - learning_rate: 0.0010
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 3.3969e-04 - learning_rate: 0.0010
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 3.3446e-04 - learning_rate: 0.0010
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 3.2933e-04 - learning_rate: 0.0010
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 3.2433e-04 - learning_rate: 0.0010
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 3.1945e-04 - learning_rate: 0.0010
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 3.1467e-04 - learning_rate: 0.0010
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 3.1002e-04 - learning_rate: 0.0010
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 3.0548e-04 - learning_rate: 0.0010
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 3.0103e-04 - learning_rate: 0.0010
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 2.9668e-04 - learning_rate: 0.0010
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 1.0000 - loss: 2.9244e-04 - learning_rate: 0.0010
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step - accuracy: 1.0000 - loss: 2.8829e-04 - learning_rate: 0.0010
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 329ms/step - accuracy: 1.0000 - loss: 2.8422e-04 - learning_rate: 0.0010
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 1.0000 - loss: 2.8026e-04 - learning_rate: 0.0010
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 2.7638e-04 - learning_rate: 0.0010
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 2.7257e-04 - learning_rate: 0.0010
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 2.6886e-04 - learning_rate: 0.0010
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 2.6521e-04 - learning_rate: 0.0010
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 2.6166e-04 - learning_rate: 0.0010
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 2.5817e-04 - learning_rate: 0.0010
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 2.5476e-04 - learning_rate: 0.0010
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 2.5141e-04 - learning_rate: 0.0010
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 2.4813e-04 - learning_rate: 0.0010
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 2.4492e-04 - learning_rate: 0.0010
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 2.4176e-04 - learning_rate: 0.0010
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 2.3870e-04 - learning_rate: 0.0010
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 2.3566e-04 - learning_rate: 0.0010
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 2.3270e-04 - learning_rate: 0.0010
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 2.2980e-04 - learning_rate: 0.0010
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 2.2695e-04 - learning_rate: 0.0010
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 2.2415e-04 - learning_rate: 0.0010
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 2.2141e-04 - learning_rate: 0.0010
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 2.1872e-04 - learning_rate: 0.0010
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 2.1610e-04 - learning_rate: 0.0010
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 2.1351e-04 - learning_rate: 0.0010
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 2.1096e-04 - learning_rate: 0.0010
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 2.0847e-04 - learning_rate: 0.0010
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 2.0601e-04 - learning_rate: 0.0010
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 2.0360e-04 - learning_rate: 0.0010
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 2.0124e-04 - learning_rate: 0.0010
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 1.9892e-04 - learning_rate: 0.0010
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 1.9664e-04 - learning_rate: 0.0010
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 1.9441e-04 - learning_rate: 0.0010
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 1.0000 - loss: 1.9221e-04 - learning_rate: 0.0010
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 1.0000 - loss: 1.9005e-04 - learning_rate: 0.0010
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 1.8793e-04 - learning_rate: 0.0010
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 1.8585e-04 - learning_rate: 0.0010
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 1.8380e-04 - learning_rate: 0.0010
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.8178e-04 - learning_rate: 0.0010
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 1.7980e-04 - learning_rate: 0.0010
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 1.7786e-04 - learning_rate: 0.0010
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.7595e-04 - learning_rate: 0.0010
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 1.7407e-04 - learning_rate: 0.0010
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 1.7222e-04 - learning_rate: 0.0010
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 1.7041e-04 - learning_rate: 0.0010
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 1.6860e-04 - learning_rate: 0.0010
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 1.6685e-04 - learning_rate: 0.0010
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 1.6512e-04 - learning_rate: 0.0010
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 1.6343e-04 - learning_rate: 0.0010
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 1.6176e-04 - learning_rate: 0.0010
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 1.6012e-04 - learning_rate: 0.0010
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 1.5848e-04 - learning_rate: 0.0010
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 1.5689e-04 - learning_rate: 0.0010
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 1.5533e-04 - learning_rate: 0.0010
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 1.5378e-04 - learning_rate: 0.0010
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 1.5226e-04 - learning_rate: 0.0010
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 1.5077e-04 - learning_rate: 0.0010
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 1.4929e-04 - learning_rate: 0.0010
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 1.4784e-04 - learning_rate: 0.0010
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 1.4643e-04 - learning_rate: 0.0010
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 1.4501e-04 - learning_rate: 0.0010
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 1.4363e-04 - learning_rate: 0.0010
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 1.4226e-04 - learning_rate: 0.0010
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 1.4092e-04 - learning_rate: 0.0010
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 1.3960e-04 - learning_rate: 0.0010
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.3829e-04 - learning_rate: 0.0010
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 1.3700e-04 - learning_rate: 0.0010
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 1.3573e-04 - learning_rate: 0.0010
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 1.3448e-04 - learning_rate: 0.0010
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 1.3326e-04 - learning_rate: 0.0010
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 1.3203e-04 - learning_rate: 0.0010
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 1.0000 - loss: 1.3084e-04 - learning_rate: 0.0010
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 1.2965e-04 - learning_rate: 0.0010
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 1.0000 - loss: 1.2849e-04 - learning_rate: 0.0010
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 1.0000 - loss: 1.2734e-04 - learning_rate: 0.0010
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 1.2622e-04 - learning_rate: 0.0010
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.2511e-04 - learning_rate: 0.0010
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 1.2401e-04 - learning_rate: 0.0010
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 1.2292e-04 - learning_rate: 0.0010
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 1.2184e-04 - learning_rate: 0.0010
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.2078e-04 - learning_rate: 0.0010
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 1.1975e-04 - learning_rate: 0.0010
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 1.1872e-04 - learning_rate: 0.0010
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 1.1770e-04 - learning_rate: 0.0010
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 1.1670e-04 - learning_rate: 0.0010
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 1.1571e-04 - learning_rate: 0.0010
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 1.1474e-04 - learning_rate: 0.0010
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 1.1377e-04 - learning_rate: 0.0010
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.1283e-04 - learning_rate: 0.0010
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 1.1189e-04 - learning_rate: 0.0010
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 1.1095e-04 - learning_rate: 0.0010
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 1.1004e-04 - learning_rate: 0.0010
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 1.0915e-04 - learning_rate: 0.0010
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 1.0826e-04 - learning_rate: 0.0010
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.0748e-04 - learning_rate: 5.0000e-04
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 1.0705e-04 - learning_rate: 5.0000e-04
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 1.0661e-04 - learning_rate: 5.0000e-04
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 1.0617e-04 - learning_rate: 5.0000e-04
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.0575e-04 - learning_rate: 5.0000e-04
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 1.0533e-04 - learning_rate: 5.0000e-04
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 1.0491e-04 - learning_rate: 5.0000e-04
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 1.0448e-04 - learning_rate: 5.0000e-04
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 1.0406e-04 - learning_rate: 5.0000e-04
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 1.0365e-04 - learning_rate: 5.0000e-04
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 1.0324e-04 - learning_rate: 5.0000e-04
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 1.0282e-04 - learning_rate: 5.0000e-04
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 1.0000 - loss: 1.0241e-04 - learning_rate: 5.0000e-04
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 1.0000 - loss: 1.0201e-04 - learning_rate: 5.0000e-04
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 1.0160e-04 - learning_rate: 5.0000e-04
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 1.0000 - loss: 1.0118e-04 - learning_rate: 5.0000e-04
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 1.0079e-04 - learning_rate: 5.0000e-04
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 1.0038e-04 - learning_rate: 5.0000e-04
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 9.9994e-05 - learning_rate: 5.0000e-04
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 9.9583e-05 - learning_rate: 5.0000e-04
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 9.9192e-05 - learning_rate: 5.0000e-04
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 9.8790e-05 - learning_rate: 5.0000e-04
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 9.8406e-05 - learning_rate: 5.0000e-04
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 9.8018e-05 - learning_rate: 5.0000e-04
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 9.7634e-05 - learning_rate: 5.0000e-04
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 9.7240e-05 - learning_rate: 5.0000e-04
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 9.6853e-05 - learning_rate: 5.0000e-04
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 9.6478e-05 - learning_rate: 5.0000e-04
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 1.0000 - loss: 9.6099e-05 - learning_rate: 5.0000e-04
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 1.0000 - loss: 9.5712e-05 - learning_rate: 5.0000e-04
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 1.0000 - loss: 9.5336e-05 - learning_rate: 5.0000e-04
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 1.0000 - loss: 9.4970e-05 - learning_rate: 5.0000e-04
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 447ms/step - accuracy: 1.0000 - loss: 9.4591e-05 - learning_rate: 5.0000e-04
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 1.0000 - loss: 9.4216e-05 - learning_rate: 5.0000e-04
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 1.0000 - loss: 9.3846e-05 - learning_rate: 5.0000e-04
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 1.0000 - loss: 9.3471e-05 - learning_rate: 5.0000e-04
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 1.0000 - loss: 9.3102e-05 - learning_rate: 5.0000e-04
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step - accuracy: 1.0000 - loss: 9.2744e-05 - learning_rate: 5.0000e-04
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - accuracy: 1.0000 - loss: 9.2377e-05 - learning_rate: 5.0000e-04
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - accuracy: 1.0000 - loss: 9.2011e-05 - learning_rate: 5.0000e-04
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 1.0000 - loss: 9.1659e-05 - learning_rate: 5.0000e-04
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 9.1284e-05 - learning_rate: 5.0000e-04
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 1.0000 - loss: 9.0941e-05 - learning_rate: 5.0000e-04
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 1.0000 - loss: 9.0578e-05 - learning_rate: 5.0000e-04
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 1.0000 - loss: 9.0226e-05 - learning_rate: 5.0000e-04
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 8.9860e-05 - learning_rate: 5.0000e-04
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.9511e-05 - learning_rate: 5.0000e-04
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 8.9171e-05 - learning_rate: 5.0000e-04
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 8.8820e-05 - learning_rate: 5.0000e-04
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 8.8474e-05 - learning_rate: 5.0000e-04
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 8.8170e-05 - learning_rate: 2.5000e-04
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 8.8003e-05 - learning_rate: 2.5000e-04
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 8.7836e-05 - learning_rate: 2.5000e-04
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 8.7651e-05 - learning_rate: 2.5000e-04
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 8.7488e-05 - learning_rate: 2.5000e-04
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 8.7321e-05 - learning_rate: 2.5000e-04
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 8.7151e-05 - learning_rate: 2.5000e-04
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 8.6975e-05 - learning_rate: 2.5000e-04
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 8.6808e-05 - learning_rate: 2.5000e-04
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 8.6644e-05 - learning_rate: 2.5000e-04
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 8.6468e-05 - learning_rate: 2.5000e-04
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 1.0000 - loss: 8.6296e-05 - learning_rate: 2.5000e-04
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.6120e-05 - learning_rate: 2.5000e-04
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.5956e-05 - learning_rate: 2.5000e-04
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 8.5792e-05 - learning_rate: 2.5000e-04
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 8.5628e-05 - learning_rate: 2.5000e-04
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 8.5452e-05 - learning_rate: 2.5000e-04
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 1.0000 - loss: 8.5294e-05 - learning_rate: 2.5000e-04
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 8.5131e-05 - learning_rate: 2.5000e-04
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 8.4955e-05 - learning_rate: 2.5000e-04
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 8.4782e-05 - learning_rate: 2.5000e-04
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 8.4621e-05 - learning_rate: 2.5000e-04
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 8.4457e-05 - learning_rate: 2.5000e-04
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 8.4281e-05 - learning_rate: 2.5000e-04
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 8.4123e-05 - learning_rate: 2.5000e-04
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 8.3954e-05 - learning_rate: 2.5000e-04
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 8.3793e-05 - learning_rate: 2.5000e-04
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 8.3620e-05 - learning_rate: 2.5000e-04
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 8.3459e-05 - learning_rate: 2.5000e-04
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 8.3295e-05 - learning_rate: 2.5000e-04
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 8.3125e-05 - learning_rate: 2.5000e-04
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.2955e-05 - learning_rate: 2.5000e-04
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 8.2782e-05 - learning_rate: 2.5000e-04
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 8.2633e-05 - learning_rate: 2.5000e-04
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.2467e-05 - learning_rate: 2.5000e-04
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 8.2303e-05 - learning_rate: 2.5000e-04
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 8.2133e-05 - learning_rate: 2.5000e-04
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 8.1960e-05 - learning_rate: 2.5000e-04
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 8.1802e-05 - learning_rate: 2.5000e-04
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 8.1647e-05 - learning_rate: 2.5000e-04
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.1480e-05 - learning_rate: 2.5000e-04
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 8.1310e-05 - learning_rate: 2.5000e-04
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 8.1155e-05 - learning_rate: 2.5000e-04
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 8.0986e-05 - learning_rate: 2.5000e-04
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 8.0831e-05 - learning_rate: 2.5000e-04
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 8.0661e-05 - learning_rate: 2.5000e-04
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 8.0509e-05 - learning_rate: 2.5000e-04
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 8.0339e-05 - learning_rate: 2.5000e-04
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 8.0184e-05 - learning_rate: 2.5000e-04
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 8.0026e-05 - learning_rate: 2.5000e-04
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 7.9865e-05 - learning_rate: 1.2500e-04
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 7.9797e-05 - learning_rate: 1.2500e-04
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 7.9707e-05 - learning_rate: 1.2500e-04
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 7.9621e-05 - learning_rate: 1.2500e-04
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 1.0000 - loss: 7.9549e-05 - learning_rate: 1.2500e-04
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 7.9466e-05 - learning_rate: 1.2500e-04
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.9394e-05 - learning_rate: 1.2500e-04
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.9308e-05 - learning_rate: 1.2500e-04
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.9233e-05 - learning_rate: 1.2500e-04
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.9150e-05 - learning_rate: 1.2500e-04
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 1.0000 - loss: 7.9064e-05 - learning_rate: 1.2500e-04
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.8989e-05 - learning_rate: 1.2500e-04
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 7.8906e-05 - learning_rate: 1.2500e-04
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 7.8840e-05 - learning_rate: 1.2500e-04
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 7.8739e-05 - learning_rate: 1.2500e-04
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 7.8664e-05 - learning_rate: 1.2500e-04
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.8575e-05 - learning_rate: 1.2500e-04
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.8497e-05 - learning_rate: 1.2500e-04
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.8411e-05 - learning_rate: 1.2500e-04
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.8342e-05 - learning_rate: 1.2500e-04
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.8256e-05 - learning_rate: 1.2500e-04
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.8170e-05 - learning_rate: 1.2500e-04
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.8095e-05 - learning_rate: 1.2500e-04
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 7.8018e-05 - learning_rate: 1.2500e-04
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 7.7937e-05 - learning_rate: 1.2500e-04
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 7.7842e-05 - learning_rate: 1.2500e-04
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 7.7764e-05 - learning_rate: 1.2500e-04
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.7693e-05 - learning_rate: 1.2500e-04
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.7603e-05 - learning_rate: 1.2500e-04
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 7.7523e-05 - learning_rate: 1.2500e-04
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.7443e-05 - learning_rate: 1.2500e-04
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.7365e-05 - learning_rate: 1.2500e-04
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 7.7270e-05 - learning_rate: 1.2500e-04
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.7201e-05 - learning_rate: 1.2500e-04
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 7.7124e-05 - learning_rate: 1.2500e-04
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 7.7022e-05 - learning_rate: 1.2500e-04
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 7.6960e-05 - learning_rate: 1.2500e-04
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 1.0000 - loss: 7.6876e-05 - learning_rate: 1.2500e-04
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 7.6793e-05 - learning_rate: 1.2500e-04
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 7.6715e-05 - learning_rate: 1.2500e-04
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 7.6629e-05 - learning_rate: 1.2500e-04
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 7.6540e-05 - learning_rate: 1.2500e-04
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.6462e-05 - learning_rate: 1.2500e-04
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 7.6385e-05 - learning_rate: 1.2500e-04
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.6301e-05 - learning_rate: 1.2500e-04
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 7.6218e-05 - learning_rate: 1.2500e-04
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.6137e-05 - learning_rate: 1.2500e-04
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 7.6054e-05 - learning_rate: 1.2500e-04
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.5970e-05 - learning_rate: 1.2500e-04
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.5887e-05 - learning_rate: 1.2500e-04
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 7.5813e-05 - learning_rate: 1.0000e-04
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.5753e-05 - learning_rate: 1.0000e-04
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 7.5673e-05 - learning_rate: 1.0000e-04
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.5616e-05 - learning_rate: 1.0000e-04
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 7.5544e-05 - learning_rate: 1.0000e-04
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.5491e-05 - learning_rate: 1.0000e-04
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 7.5419e-05 - learning_rate: 1.0000e-04
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 7.5348e-05 - learning_rate: 1.0000e-04
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.5291e-05 - learning_rate: 1.0000e-04
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 7.5217e-05 - learning_rate: 1.0000e-04
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 7.5157e-05 - learning_rate: 1.0000e-04
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.5097e-05 - learning_rate: 1.0000e-04
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.5017e-05 - learning_rate: 1.0000e-04
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.4963e-05 - learning_rate: 1.0000e-04
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.4889e-05 - learning_rate: 1.0000e-04
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.4823e-05 - learning_rate: 1.0000e-04
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.4761e-05 - learning_rate: 1.0000e-04
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 7.4692e-05 - learning_rate: 1.0000e-04
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 1.0000 - loss: 7.4638e-05 - learning_rate: 1.0000e-04
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 1.0000 - loss: 7.4564e-05 - learning_rate: 1.0000e-04
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 1.0000 - loss: 7.4489e-05 - learning_rate: 1.0000e-04
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 7.4433e-05 - learning_rate: 1.0000e-04
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 1.0000 - loss: 7.4355e-05 - learning_rate: 1.0000e-04
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 1.0000 - loss: 7.4293e-05 - learning_rate: 1.0000e-04
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 1.0000 - loss: 7.4224e-05 - learning_rate: 1.0000e-04
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.4165e-05 - learning_rate: 1.0000e-04
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.4096e-05 - learning_rate: 1.0000e-04
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.4025e-05 - learning_rate: 1.0000e-04
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.3959e-05 - learning_rate: 1.0000e-04
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.3902e-05 - learning_rate: 1.0000e-04
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 7.3825e-05 - learning_rate: 1.0000e-04
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.3759e-05 - learning_rate: 1.0000e-04
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 1.0000 - loss: 7.3697e-05 - learning_rate: 1.0000e-04
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.3634e-05 - learning_rate: 1.0000e-04
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.3563e-05 - learning_rate: 1.0000e-04
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 7.3491e-05 - learning_rate: 1.0000e-04
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.3435e-05 - learning_rate: 1.0000e-04
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.3357e-05 - learning_rate: 1.0000e-04
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 7.3304e-05 - learning_rate: 1.0000e-04
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.3226e-05 - learning_rate: 1.0000e-04
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.3155e-05 - learning_rate: 1.0000e-04
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 7.3092e-05 - learning_rate: 1.0000e-04
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.3029e-05 - learning_rate: 1.0000e-04
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 1.0000 - loss: 7.2964e-05 - learning_rate: 1.0000e-04
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 7.2889e-05 - learning_rate: 1.0000e-04
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 7.2821e-05 - learning_rate: 1.0000e-04
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 7.2749e-05 - learning_rate: 1.0000e-04
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 7.2684e-05 - learning_rate: 1.0000e-04
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 7.2621e-05 - learning_rate: 1.0000e-04
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 7.2547e-05 - learning_rate: 1.0000e-04
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.2487e-05 - learning_rate: 1.0000e-04
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 7.2421e-05 - learning_rate: 1.0000e-04
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 7.2350e-05 - learning_rate: 1.0000e-04
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 1.0000 - loss: 7.2275e-05 - learning_rate: 1.0000e-04
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 1.0000 - loss: 7.2216e-05 - learning_rate: 1.0000e-04
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 1.0000 - loss: 7.2144e-05 - learning_rate: 1.0000e-04
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 7.2085e-05 - learning_rate: 1.0000e-04
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 7.2007e-05 - learning_rate: 1.0000e-04
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 7.1936e-05 - learning_rate: 1.0000e-04
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 7.1876e-05 - learning_rate: 1.0000e-04
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 7.1811e-05 - learning_rate: 1.0000e-04
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 1.0000 - loss: 7.1748e-05 - learning_rate: 1.0000e-04
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 1.0000 - loss: 7.1682e-05 - learning_rate: 1.0000e-04
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 1.0000 - loss: 7.1590e-05 - learning_rate: 1.0000e-04
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.1539e-05 - learning_rate: 1.0000e-04
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 1.0000 - loss: 7.1456e-05 - learning_rate: 1.0000e-04
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 7.1408e-05 - learning_rate: 1.0000e-04
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 7.1340e-05 - learning_rate: 1.0000e-04
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 1.0000 - loss: 7.1271e-05 - learning_rate: 1.0000e-04
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 1.0000 - loss: 7.1206e-05 - learning_rate: 1.0000e-04
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 1.0000 - loss: 7.1146e-05 - learning_rate: 1.0000e-04
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - accuracy: 1.0000 - loss: 7.1063e-05 - learning_rate: 1.0000e-04
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 1.0000 - loss: 7.0997e-05 - learning_rate: 1.0000e-04
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 1.0000 - loss: 7.0932e-05 - learning_rate: 1.0000e-04
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 7.0863e-05 - learning_rate: 1.0000e-04
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 7.0800e-05 - learning_rate: 1.0000e-04
# Epoch 421/500
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 7.3272e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_29892/2241997505.py in <cell line: 0>()
#       5 # verbose show the network's detail and the logs of training
#       6 cnn_cls = FCNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_cnn")
# ----> 7 cnn_cls.fit(X_train_c, y_train_mtsc)
#       8 cnn_cls_preds = cnn_cls.predict(X_test_c)
#       9 print(accuracy_score(y_test_mtsc, cnn_cls_preds))
#
# /usr/local/lib/python3.12/dist-packages/aeon/utils/decorators/method_timer.py in wrapper(*args, **kwargs)
#      40             start = time.perf_counter()
#      41             try:
# ---> 42                 return func(*args, **kwargs)
#      43             finally:
#      44                 ms = int((time.perf_counter() - start) * 1000)
#
# /usr/local/lib/python3.12/dist-packages/aeon/classification/base.py in fit(self, X, y)
#     110         X, y = self._fit_setup(X, y)
#     111
# --> 112         self._fit(X, y)
#     113
#     114         # this should happen last
#
# /usr/local/lib/python3.12/dist-packages/aeon/classification/deep_learning/_fcn.py in _fit(self, X, y)
#     292             )
#     293
# --> 294         self.history = self.training_model_.fit(
#     295             X,
#     296             y_onehot,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# you can retrieve the history of training to visualize the loss
loss = cnn_cls.history.history["loss"]
plt.plot(loss, color='blue')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Evolution of the training loss.")
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

cnn_best = tf.keras.models.load_model("best_cnn.keras", compile=False)

# %%
#get conv weights of layer 1
conv1_weights = cnn_best.layers[1].get_weights()[0]

#get conv weights of layer 2
conv2_weights = cnn_best.layers[4].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import FCNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = FCNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="FCNRegressor Predictions")

# %%
from aeon.classification.deep_learning import  TimeCNNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = TimeCNNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_time_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))

# %%
cnn_t_best = tf.keras.models.load_model("best_time_cnn.keras", compile=False)
cnn_t_best.layers

# %%
#get conv weights of layer 1
conv1_weights = cnn_t_best.layers[1].get_weights()[0]

#get conv weights of layer 2
conv2_weights = cnn_t_best.layers[3].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import  TimeCNNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = TimeCNNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="TimeCNNRegressor Predictions")

# %% [markdown]
# # Упражнения <a id='tasks'></a>
#
# 1. Взять выбранные для лабы 9 набор(ы) данных. Можно взять разные наборы для классификации/регрессии (но причину надо будет обосновать)
#
# 2. Отрисовать данные
#
# 3. Попробовать все методы классификации и регрессии, описанные в блоноте:
#     Distance-based
#     Свертки (модели семейства Rocket и Hydra)
#     Feature-based
#     Deep Learning
#
#     Для каждого подхода обучть не менее 3х разных моделей для классификации и регрессии.

# %%
from aeon.datasets import load_from_ts_file
import numpy as np

X_train, y_train = load_from_ts_file("./dataset/ECG200_TRAIN.ts", return_type="numpy2D")
X_test, y_test = load_from_ts_file("./dataset/ECG200_TEST.ts", return_type="numpy2D")

print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")
print(f"Классы в датасете: {np.unique(y_train)}")
# Out:
# Train shape: (100, 96), Test shape: (100, 96)
# Классы в датасете: ['-1' '1']

# %%
import matplotlib.pyplot as plt

def plot_ecg_examples(X, y):
    classes = np.unique(y)
    plt.figure(figsize=(15, 5))

    for i, cls in enumerate(classes):
        idx = np.where(y == cls)[0][0]
        plt.plot(X[idx], label=f"Класс {cls} (1-Normal, -1-Ischemia)")

    plt.title("Примеры сигналов ЭКГ (ECG200)")
    plt.xlabel("Время (отсчеты)")
    plt.ylabel("Амплитуда")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

plot_ecg_examples(X_train, y_train)

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier
from aeon.classification.dictionary_based import IndividualBOSS
from aeon.classification.shapelet_based import ShapeletTransformClassifier

models_dist = [
    ("k-NN DTW", KNeighborsTimeSeriesClassifier(distance="dtw")),
    ("BOSS", IndividualBOSS()),
    ("Shapelets", ShapeletTransformClassifier(time_limit_in_minutes=0.5))
]

# %%
from aeon.classification.convolution_based import RocketClassifier, HydraClassifier, Arsenal

models_conv = [
    ("Rocket", RocketClassifier()),
    ("Hydra", HydraClassifier()),
    ("Arsenal", Arsenal())
]

# %%
from aeon.classification.deep_learning import InceptionTimeClassifier, ResNetClassifier, FCNClassifier

models_dl = [
    ("InceptionTime", InceptionTimeClassifier(n_epochs=20, verbose=False)),
    ("ResNet", ResNetClassifier(n_epochs=20, verbose=False)),
    ("FCN", FCNClassifier(n_epochs=20, verbose=False))
]

# %%
from sklearn.metrics import accuracy_score

def run_experiment(model_groups):
    for group_name, models in model_groups:
        print(f"\n=== Группа: {group_name} ===")
        for name, clf in models:
            clf.fit(X_train, y_train)
            y_pred = clf.predict(X_test)
            acc = accuracy_score(y_test, y_pred)
            print(f"{name:15} | Accuracy: {acc:.4f}")

all_groups = [
    ("Distance/Shapelet", models_dist),
    ("Convolution (Rocket/Hydra)", models_conv),
    ("Deep Learning", models_dl)
]

run_experiment(all_groups)
# Out:
# === Группа: Distance/Shapelet ===
# k-NN DTW        | Accuracy: 0.7700
# BOSS            | Accuracy: 0.7300
# Shapelets       | Accuracy: 0.7600
#
# === Группа: Convolution (Rocket/Hydra) ===
# Rocket          | Accuracy: 0.9200
# Hydra           | Accuracy: 0.8800
# Arsenal         | Accuracy: 0.9000
#
# === Группа: Deep Learning ===
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78401bfec0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78401bfec0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 708ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# InceptionTime   | Accuracy: 0.7900
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 840ms/step
# ResNet          | Accuracy: 0.6400
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# FCN             | Accuracy: 0.3600
